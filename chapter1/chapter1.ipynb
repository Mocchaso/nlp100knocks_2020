# %% [markdown]
# # 第1章: 準備運動

# %% [markdown]
# ## 00. 文字列の逆順
# 文字列”stressed”の文字を逆に（末尾から先頭に向かって）並べた文字列を得よ．

# %%
word = "stressed"
print(word[::-1])
# Out:
# desserts

# %% [markdown]
# ## 01. 「パタトクカシーー」
# 「パタトクカシーー」という文字列の1,3,5,7文字目を取り出して連結した文字列を得よ．

# %%
word = "パタトクカシーー"
print(word[::2])
# Out:
# パトカー

# %% [markdown]
# ## 02. 「パトカー」＋「タクシー」＝「パタトクカシーー」
# 「パトカー」＋「タクシー」の文字を先頭から交互に連結して文字列「パタトクカシーー」を得よ．

# %%
word1 = "パトカー"
word2 = "タクシー"
word = ""
for c1, c2 in zip(word1, word2):
    word += c1 + c2
print(word)
# Out:
# パタトクカシーー

# %% [markdown]
# ## 03. 円周率
# “Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics.”という文を単語に分解し，各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成せよ．

# %%
sentence = "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."
sentence = sentence.replace(",", "")
sentence = sentence.replace(".", "")
all_words = sentence.split()
result = [len(word) for word in all_words]
print(result)
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]

# %% [markdown]
# ## 04. 元素記号
# “Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.”という文を単語に分解し，1, 5, 6, 7, 8, 9, 15, 16, 19番目の単語は先頭の1文字，それ以外の単語は先頭に2文字を取り出し，取り出した文字列から単語の位置（先頭から何番目の単語か）への連想配列（辞書型もしくはマップ型）を作成せよ．

# %%
sentence = "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."
sentence = sentence.replace(".", "")
all_words = sentence.split()
result = {}
target_indices = [1, 5, 6, 7, 8, 9, 15, 16, 19]
for i, word in enumerate(all_words):
    target_word = word[:1] if i + 1 in target_indices else word[:2]
    result[i + 1] = target_word
print(result)
# Out:
# {1: 'H', 2: 'He', 3: 'Li', 4: 'Be', 5: 'B', 6: 'C', 7: 'N', 8: 'O', 9: 'F', 10: 'Ne', 11: 'Na', 12: 'Mi', 13: 'Al', 14: 'Si', 15: 'P', 16: 'S', 17: 'Cl', 18: 'Ar', 19: 'K', 20: 'Ca'}

# %% [markdown]
# ## 05. n-gram
# 与えられたシーケンス（文字列やリストなど）からn-gramを作る関数を作成せよ．この関数を用い，”I am an NLPer”という文から単語bi-gram，文字bi-gramを得よ．

# %%
def ngram(sequence, n):
    result = []
    for i in range(len(sequence) - n + 1):
        result.append(sequence[i:i+n])
    return result

sentence = "I am an NLPer"

for i in range(2, 5):
    print("n = {}".format(i))
    # 単語
    # bi-gram: "I am an NLPer" -> ["I", "am"], ["am", "an"], ["an", "NLPer"]
    print(ngram(sentence.split(), i))
    # 文字
    # bi-gram: "I am an NLPer" -> "I ", " a", "am", "m ", " a", "an", "n ", " N", "NL", "LP", "Pe", "er"
    print(ngram(sentence, i))
    print()
# Out:
# n = 2
# [['I', 'am'], ['am', 'an'], ['an', 'NLPer']]
# ['I ', ' a', 'am', 'm ', ' a', 'an', 'n ', ' N', 'NL', 'LP', 'Pe', 'er']
#
# n = 3
# [['I', 'am', 'an'], ['am', 'an', 'NLPer']]
# ['I a', ' am', 'am ', 'm a', ' an', 'an ', 'n N', ' NL', 'NLP', 'LPe', 'Per']
#
# n = 4
# [['I', 'am', 'an', 'NLPer']]
# ['I am', ' am ', 'am a', 'm an', ' an ', 'an N', 'n NL', ' NLP', 'NLPe', 'LPer']

# %% [markdown]
# ## 06. 集合
# “paraparaparadise”と”paragraph”に含まれる文字bi-gramの集合を，それぞれ, XとYとして求め，XとYの和集合，積集合，差集合を求めよ．さらに，’se’というbi-gramがXおよびYに含まれるかどうかを調べよ．

# %%
word1 = "paraparaparadise"
word2 = "paragraph"
X = ngram(word1, 2)
Y = ngram(word2, 2)
print("X = {}".format(X))
print("Y = {}".format(Y))

print("和集合: {}".format(set(X) | set(Y)))
print("積集合: {}".format(set(X) & set(Y)))
print("差集合: {}".format(set(X) - set(Y)))
print("'se'というbi-gramがXおよびYに含まれるか: {}".format("se" in (set(X) & set(Y))))
# Out:
# X = ['pa', 'ar', 'ra', 'ap', 'pa', 'ar', 'ra', 'ap', 'pa', 'ar', 'ra', 'ad', 'di', 'is', 'se']
# Y = ['pa', 'ar', 'ra', 'ag', 'gr', 'ra', 'ap', 'ph']
# 和集合: {'se', 'di', 'gr', 'ar', 'ap', 'ag', 'ra', 'ad', 'ph', 'is', 'pa'}
# 積集合: {'ra', 'ap', 'ar', 'pa'}
# 差集合: {'ad', 'se', 'di', 'is'}
# 'se'というbi-gramがXおよびYに含まれるか: False

# %% [markdown]
# # 07. テンプレートによる文生成
# 引数x, y, zを受け取り「x時のyはz」という文字列を返す関数を実装せよ．さらに，x=12, y=”気温”, z=22.4として，実行結果を確認せよ．

# %%
def generate_sentence(x, y, z):
    return "{}時の{}は{}".format(x, y, z)

print(generate_sentence(12, "気温", 22.4))
# Out:
# 12時の気温は22.4

# %% [markdown]
# ## 08. 暗号文
# 与えられた文字列の各文字を，以下の仕様で変換する関数cipherを実装せよ．
#
# * 英小文字ならば(219 - 文字コード)の文字に置換
# * その他の文字はそのまま出力
#
# この関数を用い，英語のメッセージを暗号化・復号化せよ．

# %%
def cipher(text):
    return "".join([chr(219 - ord(c)) if c.islower() else c for c in text])

text = "hello, world."
encrypted_text = cipher(text)
print("暗号化: {}".format(encrypted_text))
print("複合化: {}".format(cipher(encrypted_text)))
# Out:
# 暗号化: svool, dliow.
# 複合化: hello, world.

# %% [markdown]
# ## 09. Typoglycemia
# スペースで区切られた単語列に対して，各単語の先頭と末尾の文字は残し，それ以外の文字の順序をランダムに並び替えるプログラムを作成せよ．ただし，長さが４以下の単語は並び替えないこととする．適当な英語の文（例えば”I couldn’t believe that I could actually understand what I was reading : the phenomenal power of the human mind .”）を与え，その実行結果を確認せよ．

# %%
import random

def typoglycemia(words):
    # タイポグリセミア（単語の最初と最後以外の文字が入れ替わっても、読み取れてしまう現象）
    result = ""
    for word in words:
        if len(word) > 4:
            start_char = word[0]
            shuffled_chars = random.sample(list(word[1:-1]), len(word[1:-1]))
            end_char = word[-1]
            word = "".join([start_char] + shuffled_chars + [end_char])
        result += word
        print(word)
    return result

sentence = "I couldn’t believe that I could actually understand what I was reading : the phenomenal power of the human mind ."
print("シャッフル結果: {}".format(typoglycemia(sentence.split())))
# Out:
# I
# cun’dlot
# bieleve
# that
# I
# cloud
# aaltcluy
# udannsretd
# what
# I
# was
# reaidng
# :
# the
# pnaemhoenl
# pweor
# of
# the
# hmaun
# mind
# .
# シャッフル結果: Icun’dlotbielevethatIcloudaaltcluyudannsretdwhatIwasreaidng:thepnaemhoenlpweorofthehmaunmind.
